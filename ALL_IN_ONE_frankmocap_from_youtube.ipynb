# %% [markdown]
# # Run FrankMoCap from YouTube

# %%
# %run 00_process_youtube_videos.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
# [./videos] created.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# Processing [Yw3lYf4hYaQ_full.mp4]
# [youtube] Yw3lYf4hYaQ: Downloading webpage
# [youtube] Yw3lYf4hYaQ: Downloading js player 490079fb
# [youtube] Yw3lYf4hYaQ: Downloading js player 490079fb
# [download] Destination: videos/Yw3lYf4hYaQ_full.mp4
# [download] 100% of 11.97MiB in 00:0113MiB/s ETA 00:002
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
# Processing [jnE2DihdnS4_full.mp4]
# [youtube] jnE2DihdnS4: Downloading webpage
# [download] Destination: videos/jnE2DihdnS4_full.mp4
# [download] 100% of 8.99MiB in 00:0015MiB/s ETA 00:002
#
# We have downloaded [2] videos.
#  [Yw3lYf4hYaQ_full.mp4]
#  [jnE2DihdnS4_full.mp4]
# chunk:  21%|██        | 46/221 [00:00<00:00, 456.62it/s, now=None]
# FPS:  30.0 --------------> 10
# Moviepy - Building video videos/Yw3lYf4hYaQ.mp4.
# MoviePy - Writing audio in Yw3lYf4hYaQTEMP_MPY_wvf_snd.mp3
# t:  14%|█▍        | 14/100 [00:00<00:00, 136.39it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video videos/Yw3lYf4hYaQ.mp4
# Moviepy - Done !
# Moviepy - video ready videos/Yw3lYf4hYaQ.mp4
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# Full video path:[videos/Yw3lYf4hYaQ_full.mp4]
# chunk:  20%|█▉        | 44/221 [00:00<00:00, 435.85it/s, now=None]
# FPS:  30.0 --------------> 10
# Moviepy - Building video videos/jnE2DihdnS4.mp4.
# MoviePy - Writing audio in jnE2DihdnS4TEMP_MPY_wvf_snd.mp3
# t:  13%|█▎        | 13/100 [00:00<00:00, 127.35it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video videos/jnE2DihdnS4.mp4
# Moviepy - Done !
# Moviepy - video ready videos/jnE2DihdnS4.mp4
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
# Full video path:[videos/jnE2DihdnS4_full.mp4]
# [./images] created.
# Reading [videos/Yw3lYf4hYaQ.mp4]
# [100] images saved.
# Reading [videos/jnE2DihdnS4.mp4]
# [100] images saved.

# %%
os.environ['MKL_THREADING_LAYER'] = 'GNU'
# %run 01_extract_mocap_results.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
#
# video_ids:['Yw3lYf4hYaQ', 'jnE2DihdnS4']
# config.read_type:[images]
#  target_path:[/daintlab/home/rilab/github/frankmocap_notebooks/images/Yw3lYf4hYaQ]
#  target_path:[/daintlab/home/rilab/github/frankmocap_notebooks/images/jnE2DihdnS4]
# [./mocaps/Yw3lYf4hYaQ] created.
# [./mocaps/jnE2DihdnS4] created.
# Things will be saved into [/daintlab/home/rilab/github/frankmocap_notebooks/mocaps]
# Change the dir to [/daintlab/home/rilab/github/frankmocap_notebooks/frankmocap]
# Processing [Yw3lYf4hYaQ] ... It would take a long time...
# Processing [jnE2DihdnS4] ... It would take a long time...
# Change the dir to [/daintlab/home/rilab/github/frankmocap_notebooks]
# Done.

# %%
# %run 02_preprocess_mocap_result.ipynb
# Out:
# Done.
# [./skeletons_pkl] created.
# [./skeletons_npz] created.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
#
# video_idx:['Yw3lYf4hYaQ', 'jnE2DihdnS4']
# [mocaps/Yw3lYf4hYaQ/bbox] created.
# [mocaps/Yw3lYf4hYaQ/mocap] created.
# [skeletons_pkl/Yw3lYf4hYaQ] created.
# [skeletons_npz/Yw3lYf4hYaQ] created.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# [mocaps/jnE2DihdnS4/bbox] created.
# [mocaps/jnE2DihdnS4/mocap] created.
# [skeletons_pkl/jnE2DihdnS4] created.
# [skeletons_npz/jnE2DihdnS4] created.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=99.0), HTML(value='')))
# Done.

# %%
# %run 03_visualize_processed_pkl_and_npz.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
#
# video_idx:['Yw3lYf4hYaQ', 'jnE2DihdnS4']
# Done.

# %%
# %run 04_make_video.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Yw3lYf4hYaQ] [15.00]s~[25.00]s
# YouTube URL:[https://www.youtube.com/watch?v=jnE2DihdnS4] [15.00]s~[25.00]s
#
# video_idx:['Yw3lYf4hYaQ', 'jnE2DihdnS4']
# t:  13%|█▎        | 13/100 [00:00<00:00, 129.16it/s, now=None]
# Moviepy - Building video videos/Yw3lYf4hYaQ_final.mp4.
# Moviepy - Writing video videos/Yw3lYf4hYaQ_final.mp4
# Moviepy - Done !
# Moviepy - video ready videos/Yw3lYf4hYaQ_final.mp4
# [videos/Yw3lYf4hYaQ_final.mp4] saved.
# t:  14%|█▍        | 14/99 [00:00<00:00, 133.82it/s, now=None]
# Moviepy - Building video videos/jnE2DihdnS4_final.mp4.
# Moviepy - Writing video videos/jnE2DihdnS4_final.mp4
# Moviepy - Done !
# Moviepy - video ready videos/jnE2DihdnS4_final.mp4
# [videos/jnE2DihdnS4_final.mp4] saved.
# Done.
# Done.

# %%
print ("Done")
# Out:
# Done
