# %% [markdown]
# # Run FrankMoCap from YouTube

# %%
# %run 10_process_mp4_videos.ipynb
# Out:
# Done.
# Name:[MVI_0004] [0.00]s~[0.00]s
# Name:[1X5A1789] [0.00]s~[0.00]s
# video_ids:['MVI_0004', '1X5A1789']
# chunk:   5%|▍         | 102/2124 [00:00<00:02, 1009.73it/s, now=None]
# Moviepy - Building video ./source_videos/MVI_0004_clip.mp4.
# MoviePy - Writing audio in MVI_0004_clipTEMP_MPY_wvf_snd.mp3
# t:   1%|          | 6/964 [00:00<00:17, 55.94it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./source_videos/MVI_0004_clip.mp4
# Moviepy - Done !
# Moviepy - video ready ./source_videos/MVI_0004_clip.mp4
# [0/2](0.0~0.0) [./source_videos/MVI_0004.mp4]=>[./source_videos/MVI_0004_clip.mp4]
# chunk:   5%|▌         | 102/1889 [00:00<00:01, 970.20it/s, now=None]
# Moviepy - Building video ./source_videos/1X5A1789_clip.mp4.
# MoviePy - Writing audio in 1X5A1789_clipTEMP_MPY_wvf_snd.mp3
# t:   1%|          | 5/857 [00:00<00:18, 46.90it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video ./source_videos/1X5A1789_clip.mp4
# Moviepy - Done !
# Moviepy - video ready ./source_videos/1X5A1789_clip.mp4
# [1/2](0.0~0.0) [./source_videos/1X5A1789.mp4]=>[./source_videos/1X5A1789_clip.mp4]
# Done.
# [././images] created.
#
# [0/2] [964] images saved from [./source_videos/MVI_0004_clip.mp4] to [./images/MVI_0004].
# [1/2] [857] images saved from [./source_videos/1X5A1789_clip.mp4] to [./images/1X5A1789].
# Done.

# %%
os.environ['MKL_THREADING_LAYER'] = 'GNU'
# %run 11_extract_mocap_results.ipynb
# Out:
# Done.
# Name:[MVI_0004] [0.00]s~[0.00]s
# Name:[1X5A1789] [0.00]s~[0.00]s
# video_ids:['MVI_0004', '1X5A1789']
# [mocaps/MVI_0004] created.
# [mocaps/1X5A1789] created.
# Done.
# /daintlab/home/rilab/github/frankmocap_notebooks/mocaps
# Change directory to [/daintlab/home/rilab/github/frankmocap_notebooks/frankmocap]
# [0/2][MVI_0004]
# [1/2][1X5A1789]
# Change directory to [/daintlab/home/rilab/github/frankmocap_notebooks]
# Done.

# %%
# %run 12_preprocess_mocap_result.ipynb
# Out:
# Done.
# Name:[MVI_0004] [0.00]s~[0.00]s
# Name:[1X5A1789] [0.00]s~[0.00]s
# video_ids:['MVI_0004', '1X5A1789']
# [./skeletons_pkl] created.
# [./skeletons_npz] created.
# [0] [MVI_0004]
#  [mocaps/MVI_0004/bbox] created.
#  [mocaps/MVI_0004/mocap] created.
#  [skeletons_pkl/MVI_0004] created.
#  [skeletons_npz/MVI_0004] created.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=964.0), HTML(value='')))
# [1] [1X5A1789]
#  [mocaps/1X5A1789/bbox] created.
#  [mocaps/1X5A1789/mocap] created.
#  [skeletons_pkl/1X5A1789] created.
#  [skeletons_npz/1X5A1789] created.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=857.0), HTML(value='')))
# Done.

# %%
# %run 13_visualize_processed_pkl_and_npz.ipynb
# Out:
# Done.
# Name:[MVI_0004] [0.00]s~[0.00]s
# Name:[1X5A1789] [0.00]s~[0.00]s
# video_ids:['MVI_0004', '1X5A1789']
# [0/2] [MVI_0004]
# [1/2] [1X5A1789]
# Done.

# %%
# %run 14_make_video.ipynb
# Out:
# Done.
# Name:[MVI_0004] [0.00]s~[0.00]s
# Name:[1X5A1789] [0.00]s~[0.00]s
# video_ids:['MVI_0004', '1X5A1789']
# [0/2] [MVI_0004]
# t:   0%|          | 0/964 [00:00<?, ?it/s, now=None]
# Moviepy - Building video videos/MVI_0004_final.mp4.
# Moviepy - Writing video videos/MVI_0004_final.mp4
# Moviepy - Done !
# Moviepy - video ready videos/MVI_0004_final.mp4
# [videos/MVI_0004_final.mp4] saved.
# [1/2] [1X5A1789]
# Moviepy - Building video videos/1X5A1789_final.mp4.
# Moviepy - Writing video videos/1X5A1789_final.mp4
# Moviepy - Done !
# Moviepy - video ready videos/1X5A1789_final.mp4
# [videos/1X5A1789_final.mp4] saved.
# Done.
# Done.

# %%
print ("Done")
# Out:
# Done
