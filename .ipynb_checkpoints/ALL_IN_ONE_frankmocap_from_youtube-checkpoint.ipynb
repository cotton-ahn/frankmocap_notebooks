# %% [markdown]
# # Run FrankMoCap from YouTube

# %%
# %run 00_process_youtube_videos.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
# [./videos] created.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
# Processing [Ldu3Cc-iJP8_full.mp4]
# [youtube] Ldu3Cc-iJP8: Downloading webpage
# [youtube] Ldu3Cc-iJP8: Downloading MPD manifest
# [download] Destination: videos/Ldu3Cc-iJP8_full.mp4
# [download] 100% of 16.30MiB in 00:0539MiB/s ETA 00:0015
#
# We have downloaded [1] videos.
#  [Ldu3Cc-iJP8_full.mp4]
# chunk:  16%|█▌        | 38/243 [00:00<00:00, 378.26it/s, now=None]
# FPS:  29.97002997002997 --------------> 10
# Moviepy - Building video videos/Ldu3Cc-iJP8.mp4.
# MoviePy - Writing audio in Ldu3Cc-iJP8TEMP_MPY_wvf_snd.mp3
# t:   5%|▌         | 6/110 [00:00<00:01, 55.81it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video videos/Ldu3Cc-iJP8.mp4
# Moviepy - Done !
# Moviepy - video ready videos/Ldu3Cc-iJP8.mp4
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
# Full video path:[videos/Ldu3Cc-iJP8_full.mp4]
# [./images] created.
# Reading [videos/Ldu3Cc-iJP8.mp4]
# [110] images saved.

# %%
os.environ['MKL_THREADING_LAYER'] = 'GNU'
# %run 01_extract_mocap_results.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
#
# video_ids:['Ldu3Cc-iJP8']
# config.read_type:[images]
#  target_path:[/daintlab/home/rilab/github/frankmocap_notebooks/images/Ldu3Cc-iJP8]
# [./mocaps/Ldu3Cc-iJP8] created.
# Things will be saved into [/daintlab/home/rilab/github/frankmocap_notebooks/mocaps]
# Change the dir to [/daintlab/home/rilab/github/frankmocap_notebooks/frankmocap]
# Processing [Ldu3Cc-iJP8] ... It would take a long time...
# Change the dir to [/daintlab/home/rilab/github/frankmocap_notebooks]
# Done.

# %%
# %run 02_preprocess_mocap_result.ipynb
# Out:
# Done.
# [./skeletons_pkl] created.
# [./skeletons_npz] created.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
#
# video_idx:['Ldu3Cc-iJP8']
# [mocaps/Ldu3Cc-iJP8/bbox] created.
# [mocaps/Ldu3Cc-iJP8/mocap] created.
# [skeletons_pkl/Ldu3Cc-iJP8] created.
# [skeletons_npz/Ldu3Cc-iJP8] created.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=110.0), HTML(value='')))
# Done.

# %%
# %run 03_visualize_processed_pkl_and_npz.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
#
# video_idx:['Ldu3Cc-iJP8']
# Done.

# %%
# %run 04_make_video.ipynb
# Out:
# Done.
# YouTube URL:[https://www.youtube.com/watch?v=Ldu3Cc-iJP8] [68.00]s~[79.00]s
#
# video_idx:['Ldu3Cc-iJP8']
# t:  12%|█▏        | 13/110 [00:00<00:00, 123.29it/s, now=None]
# Moviepy - Building video videos/Ldu3Cc-iJP8_final.mp4.
# Moviepy - Writing video videos/Ldu3Cc-iJP8_final.mp4
# Moviepy - Done !
# Moviepy - video ready videos/Ldu3Cc-iJP8_final.mp4
# [videos/Ldu3Cc-iJP8_final.mp4] saved.
# Done.

# %%
print ("Done")
# Out:
# Done
